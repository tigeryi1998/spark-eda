# %%
from pyspark.sql import SparkSession

import pandas as pd 
import matplotlib.pyplot as plt 

from pyspark.sql.functions import countDistinct, desc, to_timestamp, udf, col
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType, StringType

import json

# %matplotlib inline

# %%
# https://central.sonatype.com/search?q=spark-sql-kafka

# https://spark.apache.org/docs/latest/streaming/structured-streaming-kafka-integration.html

# https://hub.docker.com/r/jupyter/pyspark-notebook/tags?name=spark

# https://central.sonatype.com/artifact/org.apache.spark/spark-sql-kafka-0-10_2.12/3.5.0

spark = (
    SparkSession.builder
      .appName("eda")
      .config("spark.driver.memory", "6g")
      .config("spark.executor.memory", "6g")
      .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0")
      .getOrCreate()
)

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://1057556fd05f:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>eda</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.version
# Out:
# '3.5.0'

# %%
spark.sparkContext._jsc
# Out:
# JavaObject id=o22

# %%
# spark.sparkContext._conf.getAll()

# %%
spark.sparkContext.getConf().get("spark.jars.packages")
# Out:
# 'org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0'

# %%
spark.sparkContext._jvm.scala.util.Properties.versionString()
# Out:
# 'version 2.12.18'

# %%
# (base) jovyan@3d4ee2b03dca:~$ spark-submit --version
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 3.5.0
#       /_/
                        
# Using Scala version 2.12.18, OpenJDK 64-Bit Server VM, 17.0.8.1
# Branch HEAD
# Compiled by user ubuntu on 2023-09-09T01:53:20Z
# Revision ce5ddad990373636e94071e7cef2f31021add07b
# Url https://github.com/apache/spark
# Type --help for more information.

# %%
import socket

# host = "3.80.138.59"
host = "kafka"
port = 9092

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
sock.settimeout(5)  # 5 second timeout

try:
    sock.connect((host, port))
    print("Connection successful!")
except Exception as e:
    print("Connection failed:", e)
finally:
    sock.close()
# Out:
# Connection successful!

# %%
# Cells below no longer works
# Do NOT run any cells below
# Just the past example 

# 3.80.138.59:9092 is down 
# but kafka:9092 is connecting fine 
# just nothing in kafka:9092 yet

# %%
df = spark.read.format("kafka") \
                .option("kafka.bootstrap.servers", "3.80.138.59:9092") \
                .option("subscribe", "health_events") \
                .option("startingOffsets", "earliest") \
                .option("endingOffsets", "latest").load()

# %%
df.count()

# %%
df.show(2)
# Out:
# +----+--------------------+-------------+---------+------+--------------------+-------------+
# | key|               value|        topic|partition|offset|           timestamp|timestampType|
# +----+--------------------+-------------+---------+------+--------------------+-------------+
# |null|[7B 22 45 76 65 6...|health_events|        0|290358|2024-11-03 19:51:...|            0|
# |null|[7B 22 45 76 65 6...|health_events|        0|290359|2024-11-03 19:51:...|            0|
# +----+--------------------+-------------+---------+------+--------------------+-------------+
# only showing top 2 rows

# %%
def decode_value(x):
    if x is not None:
        try:
            return bytes(x).decode("utf-8")
        except:
            return None

# %%
from pyspark.sql.functions import udf

from pyspark.sql.types import StringType, IntegerType

# %%
decode_value_udf = udf(decode_value, StringType())

# %%
df = df.withColumn("value_decode", decode_value_udf("value"))

# %%
df.show(2, truncate=False)
# Out:
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+------+-----------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |key |value                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |topic        |partition|offset|timestamp              |timestampType|value_decode                                                                                                                                                           |
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+------+-----------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |null|[7B 22 45 76 65 6E 74 54 79 70 65 22 3A 20 22 68 65 61 6C 74 68 5F 6D 65 6E 74 69 6F 6E 22 2C 20 22 54 69 6D 65 73 74 61 6D 70 22 3A 20 22 32 30 32 34 2D 31 31 2D 30 33 20 31 39 3A 35 31 3A 31 37 22 2C 20 22 4C 6F 63 61 74 69 6F 6E 22 3A 20 22 42 65 72 6C 69 6E 22 2C 20 22 53 65 76 65 72 69 74 79 22 3A 20 22 6D 65 64 69 75 6D 22 2C 20 22 44 65 74 61 69 6C 73 22 3A 20 22 54 68 69 73 20 69 73 20 61 20 73 69 6D 75 6C 61 74 65 64 20 68 65 61 6C 74 68 5F 6D 65 6E 74 69 6F 6E 20 65 76 65 6E 74 2E 22 7D]|health_events|0        |290358|2024-11-03 19:51:17.951|0            |{"EventType": "health_mention", "Timestamp": "2024-11-03 19:51:17", "Location": "Berlin", "Severity": "medium", "Details": "This is a simulated health_mention event."}|
# |null|[7B 22 45 76 65 6E 74 54 79 70 65 22 3A 20 22 76 61 63 63 69 6E 61 74 69 6F 6E 22 2C 20 22 54 69 6D 65 73 74 61 6D 70 22 3A 20 22 32 30 32 34 2D 31 31 2D 30 33 20 31 39 3A 35 31 3A 33 33 22 2C 20 22 4C 6F 63 61 74 69 6F 6E 22 3A 20 22 4C 6F 73 20 41 6E 67 65 6C 65 73 22 2C 20 22 53 65 76 65 72 69 74 79 22 3A 20 22 6D 65 64 69 75 6D 22 2C 20 22 44 65 74 61 69 6C 73 22 3A 20 22 54 68 69 73 20 69 73 20 61 20 73 69 6D 75 6C 61 74 65 64 20 76 61 63 63 69 6E 61 74 69 6F 6E 20 65 76 65 6E 74 2E 22 7D]   |health_events|0        |290359|2024-11-03 19:51:33.951|0            |{"EventType": "vaccination", "Timestamp": "2024-11-03 19:51:33", "Location": "Los Angeles", "Severity": "medium", "Details": "This is a simulated vaccination event."} |
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+------+-----------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 2 rows

# %%
import json

# %%
def get_eventtype(json_str):
    if json_str is not None:
        try:
            d = json.loads(json_str)
            return d["EventType"]
        except:
            return None

# %%
get_eventtype_udf = udf(get_eventtype, StringType())

# %%
df = df.withColumn("event_type", get_eventtype_udf("value_decode"))

# %%
df.show(2, truncate = False)
# Out:
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+------+-----------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+
# |key |value                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |topic        |partition|offset|timestamp              |timestampType|value_decode                                                                                                                                                           |event_type    |
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+------+-----------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+
# |null|[7B 22 45 76 65 6E 74 54 79 70 65 22 3A 20 22 68 65 61 6C 74 68 5F 6D 65 6E 74 69 6F 6E 22 2C 20 22 54 69 6D 65 73 74 61 6D 70 22 3A 20 22 32 30 32 34 2D 31 31 2D 30 33 20 31 39 3A 35 31 3A 31 37 22 2C 20 22 4C 6F 63 61 74 69 6F 6E 22 3A 20 22 42 65 72 6C 69 6E 22 2C 20 22 53 65 76 65 72 69 74 79 22 3A 20 22 6D 65 64 69 75 6D 22 2C 20 22 44 65 74 61 69 6C 73 22 3A 20 22 54 68 69 73 20 69 73 20 61 20 73 69 6D 75 6C 61 74 65 64 20 68 65 61 6C 74 68 5F 6D 65 6E 74 69 6F 6E 20 65 76 65 6E 74 2E 22 7D]|health_events|0        |290358|2024-11-03 19:51:17.951|0            |{"EventType": "health_mention", "Timestamp": "2024-11-03 19:51:17", "Location": "Berlin", "Severity": "medium", "Details": "This is a simulated health_mention event."}|health_mention|
# |null|[7B 22 45 76 65 6E 74 54 79 70 65 22 3A 20 22 76 61 63 63 69 6E 61 74 69 6F 6E 22 2C 20 22 54 69 6D 65 73 74 61 6D 70 22 3A 20 22 32 30 32 34 2D 31 31 2D 30 33 20 31 39 3A 35 31 3A 33 33 22 2C 20 22 4C 6F 63 61 74 69 6F 6E 22 3A 20 22 4C 6F 73 20 41 6E 67 65 6C 65 73 22 2C 20 22 53 65 76 65 72 69 74 79 22 3A 20 22 6D 65 64 69 75 6D 22 2C 20 22 44 65 74 61 69 6C 73 22 3A 20 22 54 68 69 73 20 69 73 20 61 20 73 69 6D 75 6C 61 74 65 64 20 76 61 63 63 69 6E 61 74 69 6F 6E 20 65 76 65 6E 74 2E 22 7D]   |health_events|0        |290359|2024-11-03 19:51:33.951|0            |{"EventType": "vaccination", "Timestamp": "2024-11-03 19:51:33", "Location": "Los Angeles", "Severity": "medium", "Details": "This is a simulated vaccination event."} |vaccination   |
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+------+-----------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+
# only showing top 2 rows

# %%
df = spark.read.format("kafka") \
               .option("kafka.bootstrap.servers", "3.80.138.59:9092") \
               .option("subscribe", "health_events") \
               .option("startingOffsets", "earliest") \
               .option("endingOffsets", "latest").load()

# %%
df.count()
# Out:
# 60875

# %%
df.show(2)
# Out:
# +----+--------------------+-------------+---------+------+--------------------+-------------+
# | key|               value|        topic|partition|offset|           timestamp|timestampType|
# +----+--------------------+-------------+---------+------+--------------------+-------------+
# |null|[7B 22 45 76 65 6...|health_events|        0|290358|2024-11-03 19:51:...|            0|
# |null|[7B 22 45 76 65 6...|health_events|        0|290359|2024-11-03 19:51:...|            0|
# +----+--------------------+-------------+---------+------+--------------------+-------------+
# only showing top 2 rows

# %%
df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
from pyspark.sql.functions import udf, col
from pyspark.sql.types import StringType

def decode(bs, enc="utf-8"):
    if bs is not None:
        try:
            return bytes(bs).decode(enc)
        except:
            return None
        
decode_udf = udf(decode, StringType())

# %%
df = df.withColumn("value_decoded", decode_udf("value"))

# %%
df.show(2, truncate = False)
# Out:
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+------+-----------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |key |value                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |topic        |partition|offset|timestamp              |timestampType|value_decoded                                                                                                                                                          |
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+------+-----------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |null|[7B 22 45 76 65 6E 74 54 79 70 65 22 3A 20 22 68 65 61 6C 74 68 5F 6D 65 6E 74 69 6F 6E 22 2C 20 22 54 69 6D 65 73 74 61 6D 70 22 3A 20 22 32 30 32 34 2D 31 31 2D 30 33 20 31 39 3A 35 31 3A 31 37 22 2C 20 22 4C 6F 63 61 74 69 6F 6E 22 3A 20 22 42 65 72 6C 69 6E 22 2C 20 22 53 65 76 65 72 69 74 79 22 3A 20 22 6D 65 64 69 75 6D 22 2C 20 22 44 65 74 61 69 6C 73 22 3A 20 22 54 68 69 73 20 69 73 20 61 20 73 69 6D 75 6C 61 74 65 64 20 68 65 61 6C 74 68 5F 6D 65 6E 74 69 6F 6E 20 65 76 65 6E 74 2E 22 7D]|health_events|0        |290358|2024-11-03 19:51:17.951|0            |{"EventType": "health_mention", "Timestamp": "2024-11-03 19:51:17", "Location": "Berlin", "Severity": "medium", "Details": "This is a simulated health_mention event."}|
# |null|[7B 22 45 76 65 6E 74 54 79 70 65 22 3A 20 22 76 61 63 63 69 6E 61 74 69 6F 6E 22 2C 20 22 54 69 6D 65 73 74 61 6D 70 22 3A 20 22 32 30 32 34 2D 31 31 2D 30 33 20 31 39 3A 35 31 3A 33 33 22 2C 20 22 4C 6F 63 61 74 69 6F 6E 22 3A 20 22 4C 6F 73 20 41 6E 67 65 6C 65 73 22 2C 20 22 53 65 76 65 72 69 74 79 22 3A 20 22 6D 65 64 69 75 6D 22 2C 20 22 44 65 74 61 69 6C 73 22 3A 20 22 54 68 69 73 20 69 73 20 61 20 73 69 6D 75 6C 61 74 65 64 20 76 61 63 63 69 6E 61 74 69 6F 6E 20 65 76 65 6E 74 2E 22 7D]   |health_events|0        |290359|2024-11-03 19:51:33.951|0            |{"EventType": "vaccination", "Timestamp": "2024-11-03 19:51:33", "Location": "Los Angeles", "Severity": "medium", "Details": "This is a simulated vaccination event."} |
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+---------+------+-----------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 2 rows

# %%
import json

def extract_event_type(json_str):
    if json_str is not None:
        try:
            return json.loads(json_str).get("EventType")
        except json.JSONDecodeError:
            return None
    return None

# Step 2: Register the UDF
extract_event_type_udf = udf(extract_event_type, StringType())

# Step 3: Apply the UDF to create the "EventType" column from "value_decoded"
df = df.withColumn("EventType", extract_event_type_udf(col("value_decoded")))

# %%
df.select("EventType").show()
# Out:
# +--------------------+
# |           EventType|
# +--------------------+
# |      health_mention|
# |         vaccination|
# |general_health_re...|
# |  hospital_admission|
# |     routine_checkup|
# |         vaccination|
# |         vaccination|
# |  emergency_incident|
# |  emergency_incident|
# |         vaccination|
# |         vaccination|
# |     routine_checkup|
# |      health_mention|
# |  emergency_incident|
# |  hospital_admission|
# |  hospital_admission|
# |  hospital_admission|
# |  hospital_admission|
# |general_health_re...|
# |     routine_checkup|
# +--------------------+
# only showing top 20 rows

# %%
df = spark.read.csv("customers-1000000.csv", header = True)

# %%
df.count()
# Out:
# 1000000

# %%
df.printSchema()
# Out:
# root
#  |-- Index: string (nullable = true)
#  |-- Customer Id: string (nullable = true)
#  |-- First Name: string (nullable = true)
#  |-- Last Name: string (nullable = true)
#  |-- Company: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Phone 1: string (nullable = true)
#  |-- Phone 2: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Subscription Date: string (nullable = true)
#  |-- Website: string (nullable = true)

# %%
df.show(5)
# Out:
# +-----+---------------+----------+---------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+
# |Index|    Customer Id|First Name|Last Name|             Company|       City|             Country|             Phone 1|             Phone 2|               Email|Subscription Date|             Website|
# +-----+---------------+----------+---------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+
# |    1|138fB5315da5fE9|    Jeanne|  Ferrell|          Wilcox-Fox|Tonichester|British Virgin Is...|001-995-820-0140x...|       (757)324-8634|aaronwoods@walter...|       2020-03-27|https://www.romer...|
# |    2|b0d61acAc72A388|       Ian| Browning|         Meadows Inc|  Colontown|         El Salvador|        218-383-6764|+1-213-212-0464x0742|zschultz@blevins-...|       2021-03-12|   https://ford.com/|
# |    3|1B27Ff7Fd418C89|    Taylor| Martinez|       Nicholson Inc|East Evelyn|    Marshall Islands|     +1-455-875-7024| (783)689-6710x09859|monicacoffey@mood...|       2021-08-29|http://love-moral...|
# |    4|eff8bbcED3eacD8|     Andre|   Mccall|          Cooper Ltd|   New Luis|            Colombia|   (334)358-5162x861|        016-422-2338| parkerdiana@orr.net|       2020-05-29| http://vaughan.biz/|
# |    5|73ee6AaCAcea39C|    Alyssa|   Mcneil|Arnold, Neal and ...|    New Jay|Netherlands Antilles| +1-344-219-8095x764|001-178-547-0380x...|janephillips@nich...|       2020-11-10|http://ibarra-adk...|
# +-----+---------------+----------+---------+--------------------+-----------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+
# only showing top 5 rows

# %%
### Count number of unique countries

df.select("Country").distinct().count()
# Out:
# 243

# %%
### Count number of unique countries

df.select("City").distinct().count()
# Out:
# 114893

# %%
# Which country has most number of customers

from pyspark.sql.functions import countDistinct, desc, to_timestamp
from pyspark.sql.types import IntegerType, StringType


cust_count_df = df.groupBy("Country").agg(countDistinct("Customer Id").alias("customer_count"))

# %%
city_count_df = df.groupBy("Country").agg(countDistinct("City").alias("city_count"))

# %%
## Joining

count_df = cust_count_df.join(city_count_df, on = "Country")

# %%
count_df.show()
# Out:
# +--------------------+--------------+----------+
# |             Country|customer_count|city_count|
# +--------------------+--------------+----------+
# |                Chad|          4056|      3881|
# |            Anguilla|          4049|      3844|
# |            Paraguay|          3992|      3809|
# |               Macao|          4211|      4032|
# |Heard Island and ...|          4095|      3918|
# |               Yemen|          4008|      3841|
# |             Senegal|          4005|      3822|
# |              Sweden|          4094|      3902|
# |             Tokelau|          4039|      3849|
# |            Kiribati|          4093|      3891|
# |French Southern T...|          4018|      3847|
# |              Guyana|          4134|      3963|
# |         Philippines|          4092|      3893|
# |             Eritrea|          4130|      3939|
# |              Jersey|          4016|      3827|
# |            Djibouti|          4098|      3909|
# |      Norfolk Island|          4057|      3834|
# |               Tonga|          3993|      3804|
# |           Singapore|          4042|      3852|
# |            Malaysia|          4122|      3924|
# +--------------------+--------------+----------+
# only showing top 20 rows

# %%
count_df.count()
# Out:
# 243

# %%
count_df = count_df.orderBy(desc("customer_count"))

# %%
count_df.show(5)
# Out:
# +--------------------+--------------+----------+
# |             Country|customer_count|city_count|
# +--------------------+--------------+----------+
# |               Korea|          8114|      7358|
# |               Congo|          8112|      7421|
# |        Saudi Arabia|          4249|      4061|
# |Holy See (Vatican...|          4240|      4041|
# |               Haiti|          4237|      4041|
# +--------------------+--------------+----------+
# only showing top 5 rows

# %%
count_df = count_df.toPandas()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,5))

plt.bar(count_df['Country'][:5], count_df['customer_count'][:5])

plt.show()

# %%
df = df.withColumn("date", to_timestamp("Subscription Date"))

# %%
df.show(2)
# Out:
# +-----+---------------+----------+---------+-----------+-----------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+-------------------+
# |Index|    Customer Id|First Name|Last Name|    Company|       City|             Country|             Phone 1|             Phone 2|               Email|Subscription Date|             Website|               date|
# +-----+---------------+----------+---------+-----------+-----------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+-------------------+
# |    1|138fB5315da5fE9|    Jeanne|  Ferrell| Wilcox-Fox|Tonichester|British Virgin Is...|001-995-820-0140x...|       (757)324-8634|aaronwoods@walter...|       2020-03-27|https://www.romer...|2020-03-27 00:00:00|
# |    2|b0d61acAc72A388|       Ian| Browning|Meadows Inc|  Colontown|         El Salvador|        218-383-6764|+1-213-212-0464x0742|zschultz@blevins-...|       2021-03-12|   https://ford.com/|2021-03-12 00:00:00|
# +-----+---------------+----------+---------+-----------+-----------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+-------------------+
# only showing top 2 rows

# %%
max_date = df.select(max("date")).collect()[0][0]

# %%
max_date
# Out:
# datetime.datetime(2022, 5, 29, 0, 0)

# %%
df.filter(df['date'] == max_date).show()
# Out:
# +-----+---------------+-----------+----------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+-------------------+
# |Index|    Customer Id| First Name| Last Name|             Company|               City|             Country|             Phone 1|             Phone 2|               Email|Subscription Date|             Website|               date|
# +-----+---------------+-----------+----------+--------------------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+-------------------+
# |  860|A087d8CF7E24396|     Connie|Hutchinson|      Hopkins-Reeves|          Karlaside|          Azerbaijan|001-199-101-1344x...|        220.882.7521|josephrodriguez@b...|       2022-05-29|   https://ward.net/|2022-05-29 00:00:00|
# | 1023|FfCF2f6f304b4Aa|     Briana|      Khan|       Garner-Bowers|       Shelleyshire|             Comoros|001-552-682-2428x...|       (331)705-7857|jaredroberson@per...|       2022-05-29|https://www.cerva...|2022-05-29 00:00:00|
# | 1188|54f2601DAF3A10c|       Fred|      Khan|Vega, Terrell and...|     West Lucasbury|Slovakia (Slovak ...|    339-038-7242x412| (899)535-0309x43868|jsanchez@cooley.info|       2022-05-29|http://www.lara.net/|2022-05-29 00:00:00|
# | 1475|F0cBeE2bB17f6Fe|Christopher|      Luna|         House Group|         Brockhaven|           Lithuania|        188-129-1534|        503-187-9070|monicabailey@pere...|       2022-05-29|http://www.ewing-...|2022-05-29 00:00:00|
# | 2052|184beA42F79Da1E|     Miguel| Daugherty|           Moore Inc|       New Jacobton|              Zambia|001-178-358-7017x...|          0010893502|kevinking@hoffman...|       2022-05-29| https://holden.com/|2022-05-29 00:00:00|
# | 7294|bccC80a05ddfDc5|       Todd|     Chase|         Cruz-Bowman|   South Terriville|               Sudan|        361-484-4243|       (346)092-6577|mauricewright@ber...|       2022-05-29|https://www.dudle...|2022-05-29 00:00:00|
